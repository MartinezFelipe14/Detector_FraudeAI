# %%
import pandas as pd

df = pd.read_csv('creditcard.csv')

X = df.drop('Class', axis=1).copy()

y = df['Class'].copy()

# %%
from sklearn.model_selection import train_test_split

X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size=0.2, stratify=y)

y_treino.value_counts()
# Out:
# Class
# 0    227451
# 1       394
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from imblearn.pipeline import Pipeline as imbPipeline
from imblearn.over_sampling import SMOTE

def treinar_modelo(params):
    learning_rate = params[0]
    min_child_weight = params[1]
    max_depth = params[2]
    colsample_bytree = params[3]
    gamma = params[4]
    scale_pos_weight = params[5]
    
    print(params, '\n')


    pipe = imbPipeline(steps=[('SMOTE', SMOTE()),
                              ('StandardScaler', StandardScaler()),
                              ('XGBClassifier', XGBClassifier(learning_rate=learning_rate, min_child_weight=min_child_weight,
                                                              max_depth=max_depth, colsample_bytree=colsample_bytree,
                                                              gamma=gamma, scale_pos_weight=scale_pos_weight, n_estimators=50))])


    pipe.fit(X_treino, y_treino)

    proba = pipe.predict_proba(X_teste)[:, 1]

    return -1 * roc_auc_score(y_teste, proba) # multiplicado por -1 porque é preciso minimizar a negativa do auc não o próprio auc


space = [(1e-3, 1, 'log-uniform'), # learning_rate, log-uniform dá mais importância para números menores 
         (1, 10), # min_child_weight
         (3, 10), # max_depth
         (0.5, 1.0), # colsample_bytree
         (0, 5), # gamma
         (1, 10)] # scale_pos_weight

# %%
from skopt import gp_minimize

resultados_gp = gp_minimize(treinar_modelo, space, verbose=1, n_calls=30, n_random_starts=10, acq_func='gp_hedge')
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# [0.004673447687442937, 7, 4, 0.6882157072531008, 4, 2]
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 2.3895
# Function value obtained: -0.9772
# Current minimum: -0.9772
# Iteration No: 2 started. Evaluating function at random point.
# [0.005700415612265633, 7, 8, 0.6911343750703985, 3, 4]
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 2.5284
# Function value obtained: -0.9833
# Current minimum: -0.9833
# Iteration No: 3 started. Evaluating function at random point.
# [0.0011950516558566905, 7, 8, 0.8524776192425616, 1, 10]
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 2.3926
# Function value obtained: -0.9751
# Current minimum: -0.9833
# Iteration No: 4 started. Evaluating function at random point.
# [0.04822242215552746, 5, 7, 0.7712175592293227, 0, 5]
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 2.2543
# Function value obtained: -0.9712
# Current minimum: -0.9833
# Iteration No: 5 started. Evaluating function at random point.
# [0.07087482183009883, 7, 7, 0.8776532437504074, 4, 2]
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 2.2448
# Function value obtained: -0.9598
# Current minimum: -0.9833
# Iteration No: 6 started. Evaluating function at random point.
# [0.929375343322879, 9, 6, 0.8550620440205995, 2, 2]
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 1.8592
# Function value obtained: -0.9582
# Current minimum: -0.9833
# Iteration No: 7 started. Evaluating function at random point.
# [0.0019640904110615246, 7, 5, 0.979254122451727, 4, 7]
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 1.9910
# Function value obtained: -0.9791
# Current minimum: -0.9833
# Iteration No: 8 started. Evaluating function at random point.
# [0.03809046925285492, 10, 5, 0.6724809602875379, 1, 6]
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 1.9922
# Function value obtained: -0.9834
# Current minimum: -0.9834
# Iteration No: 9 started. Evaluating function at random point.
# [0.18524536606594857, 9, 4, 0.7166964565459397, 3, 5]
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 2.4884
# Function value obtained: -0.9629
# Current minimum: -0.9834
# Iteration No: 10 started. Evaluating function at random point.
# [0.007204829286596599, 4, 4, 0.518340637057126, 2, 2]
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 2.1804
# Function value obtained: -0.9790
# Current minimum: -0.9834
# Iteration No: 11 started. Searching for the next optimal point.
# [0.012736179043544009, 10, 8, 0.5, 2, 8]
#
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 2.8997
# Function value obtained: -0.9842
# Current minimum: -0.9842
# Iteration No: 12 started. Searching for the next optimal point.
# [0.01766325106711879, 10, 4, 1.0, 2, 8]
#
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 2.1396
# Function value obtained: -0.9794
# Current minimum: -0.9842
# Iteration No: 13 started. Searching for the next optimal point.
# [0.001, 1, 7, 0.5, 0, 5]
#
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 2.7810
# Function value obtained: -0.9856
# Current minimum: -0.9856
# Iteration No: 14 started. Searching for the next optimal point.
# [0.004974219662458677, 3, 4, 0.5, 2, 6]
#
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 2.1682
# Function value obtained: -0.9826
# Current minimum: -0.9856
# Iteration No: 15 started. Searching for the next optimal point.
# [0.001, 10, 7, 0.5, 0, 4]
#
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 2.6308
# Function value obtained: -0.9847
# Current minimum: -0.9856
# Iteration No: 16 started. Searching for the next optimal point.
# [0.06616463070260868, 9, 8, 0.5, 1, 10]
#
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 2.9954
# Function value obtained: -0.9768
# Current minimum: -0.9856
# Iteration No: 17 started. Searching for the next optimal point.
# [0.0010472345232379425, 4, 3, 0.9467258448319409, 4, 1]
#
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 2.1003
# Function value obtained: -0.9595
# Current minimum: -0.9856
# Iteration No: 18 started. Searching for the next optimal point.
# [0.008558963408316538, 6, 9, 0.6534600758342584, 1, 9]
#
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 3.1824
# Function value obtained: -0.9807
# Current minimum: -0.9856
# Iteration No: 19 started. Searching for the next optimal point.
# [0.001, 5, 3, 0.5, 4, 10]
#
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 2.0280
# Function value obtained: -0.9817
# Current minimum: -0.9856
# Iteration No: 20 started. Searching for the next optimal point.
# [0.001, 8, 9, 0.6368507347363793, 1, 6]
#
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 3.2451
# Function value obtained: -0.9798
# Current minimum: -0.9856
# Iteration No: 21 started. Searching for the next optimal point.
# [1.0, 4, 7, 1.0, 3, 10]
#
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 2.5740
# Function value obtained: -0.8853
# Current minimum: -0.9856
# Iteration No: 22 started. Searching for the next optimal point.
# [0.009561472363794643, 10, 10, 0.5, 0, 1]
#
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 3.4410
# Function value obtained: -0.9858
# Current minimum: -0.9858
# Iteration No: 23 started. Searching for the next optimal point.
# [0.001, 1, 6, 0.5, 0, 10]
#
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 2.5280
# Function value obtained: -0.9816
# Current minimum: -0.9858
# Iteration No: 24 started. Searching for the next optimal point.
# [0.001, 10, 10, 0.5, 5, 10]
#
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 3.4894
# Function value obtained: -0.9769
# Current minimum: -0.9858
# Iteration No: 25 started. Searching for the next optimal point.
# [0.001, 1, 10, 0.5, 5, 10]
#
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 3.4290
# Function value obtained: -0.9761
# Current minimum: -0.9858
# Iteration No: 26 started. Searching for the next optimal point.
# [0.19282590608592157, 10, 10, 0.5, 0, 1]
#
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 3.3065
# Function value obtained: -0.9807
# Current minimum: -0.9858
# Iteration No: 27 started. Searching for the next optimal point.
# [0.005526297910797022, 6, 3, 0.5, 0, 4]
#
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 2.2603
# Function value obtained: -0.9752
# Current minimum: -0.9858
# Iteration No: 28 started. Searching for the next optimal point.
# [0.002774006443139786, 10, 10, 1.0, 0, 1]
#
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 3.7761
# Function value obtained: -0.9641
# Current minimum: -0.9858
# Iteration No: 29 started. Searching for the next optimal point.
# [1.0, 10, 3, 0.5, 5, 1]
#
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 2.2702
# Function value obtained: -0.9618
# Current minimum: -0.9858
# Iteration No: 30 started. Searching for the next optimal point.
# [0.021110214046863026, 10, 10, 0.5, 5, 1]
#
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 3.4702
# Function value obtained: -0.9765
# Current minimum: -0.9858

# %%
resultados_gp.x
# Out:
# [0.009561472363794643, 10, 10, 0.5, 0, 1]
